# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Riyank/Downloads/csv/data.csv')

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.shape
# Out:
# (89184, 86)

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly  \
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07
#
#           TaxPay(%)    first_four
# count  89184.000000  48019.000000
# mean       0.020183   4202.945209
# std        0.777875   2753.300845
# min        0.000000      1.000000
# 25%        0.000000   1600.000000
# 50%        0.000000   3700.000000
# 75%        0.000000   6425.000000
# max       30.000000   9999.000000

# %%
df.describe().transpose()
# Out:
#                        count          mean           std  min       25%  \
# ResponseId           89184.0  4.459250e+04  2.574535e+04  1.0  22296.75
# CompTotal            48225.0  1.036807e+42  2.276847e+44  0.0  63000.00
# WorkExp              43579.0  1.140513e+01  9.051989e+00  0.0      5.00
# ConvertedCompYearly  48019.0  1.031101e+05  6.814188e+05  1.0  43907.00
# TaxPay(%)            89184.0  2.018299e-02  7.778748e-01  0.0      0.00
# first_four           48019.0  4.202945e+03  2.753301e+03  1.0   1600.00
#
#                           50%        75%           max
# ResponseId            44592.5   66888.25  8.918400e+04
# CompTotal            115000.0  230000.00  5.000000e+46
# WorkExp                   9.0      16.00  5.000000e+01
# ConvertedCompYearly   74963.0  121641.00  7.435143e+07
# TaxPay(%)                 0.0       0.00  3.000000e+01
# first_four             3700.0    6425.00  9.999000e+03

# %%
df[df.ConvertedCompYearly > 1200000].count()
# Out:
# ResponseId             48
# Q120                   48
# MainBranch             48
# Age                    48
# Employment             48
#                        ..
# SurveyLength           48
# SurveyEase             48
# ConvertedCompYearly    48
# TaxPay(%)              48
# first_four             48
# Length: 86, dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\Riyank\\pandas'

# %%
df[df['ConvertedCompYearly'] > 1000000].describe()
# Out:
#          ResponseId     CompTotal    WorkExp  ConvertedCompYearly  TaxPay(%)  \
# count     60.000000  6.000000e+01  31.000000         6.000000e+01       60.0
# mean   44217.133333  2.145414e+09  18.612903         8.242048e+06       30.0
# std    24930.041118  1.316932e+10  12.018534         1.747312e+07        0.0
# min      771.000000  9.989980e+05   1.000000         1.069822e+06       30.0
# 25%    25540.250000  1.290000e+06   7.000000         1.296269e+06       30.0
# 50%    40309.500000  2.546012e+06  18.000000         2.014380e+06       30.0
# 75%    66357.500000  1.845686e+07  26.000000         5.573120e+06       30.0
# max    88904.000000  1.000000e+11  43.000000         7.435143e+07       30.0
#
#         first_four
# count    60.000000
# mean   2936.366667
# std    2501.218943
# min    1031.000000
# 25%    1257.500000
# 50%    1796.000000
# 75%    3127.000000
# max    9915.000000

# %%
df['TaxPay(%)'] = df['ConvertedCompYearly'].apply(lambda x: 30 if x > 1000000 else 0)

# %%
df[df['TaxPay(%)'] == 30].head()
# Out:
#       ResponseId     Q120                      MainBranch              Age  \
# 770          771  I agree  I am a developer by profession  25-34 years old
# 5904        5905  I agree  I am a developer by profession  18-24 years old
# 7486        7487  I agree  I am a developer by profession  35-44 years old
# 7994        7995  I agree  I am a developer by profession  45-54 years old
# 9393        9394  I agree  I am a developer by profession  35-44 years old
#
#                                              Employment  \
# 770                                 Employed, full-time
# 5904  Independent contractor, freelancer, or self-em...
# 7486                                Employed, full-time
# 7994  Independent contractor, freelancer, or self-em...
# 9393                                Employed, full-time
#
#                                 RemoteWork  \
# 770   Hybrid (some remote, some in-person)
# 5904                                Remote
# ...

# %%
option = ['Easy','Neither easy nor difficult']
df[df['SurveyEase'].isin(option)].head(2)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
#
#             Employment                            RemoteWork  \
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
#
#                                         EdLevel  \
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 1  Books / Physical media;Colleague;Friend or fam...
# 2  Books / Physical media;Colleague;On the job tr...
#
#                                      LearnCodeOnline  ...       Frequency_3  \
# ...

# %%
df[(df['ConvertedCompYearly'] > 300000) & (df['ConvertedCompYearly'] < 600000)].head()
# Out:
#       ResponseId     Q120                      MainBranch              Age  \
# 341          342  I agree  I am a developer by profession  35-44 years old
# 405          406  I agree  I am a developer by profession  55-64 years old
# 872          873  I agree  I am a developer by profession  35-44 years old
# 1000        1001  I agree  I am a developer by profession  35-44 years old
# 1205        1206  I agree  I am a developer by profession  25-34 years old
#
#                                              Employment RemoteWork  \
# 341   Independent contractor, freelancer, or self-em...     Remote
# 405   Independent contractor, freelancer, or self-em...     Remote
# 872                                 Employed, full-time     Remote
# 1000  Independent contractor, freelancer, or self-em...     Remote
# 1205                                Employed, full-time     Remote
#
#                                        CodingActivities  \
# ...

# %% [markdown]
# #__make custom function and apply it in dataframe__

# %%
def first_four(num):
    return str(num)[0:4]

# %%
df['first_four'] = df['ConvertedCompYearly'].apply(first_four)

# %%
df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: count, dtype: int64

# %%
mymap = {'Hybrid (some remote, some in-person)':'H','Remote':'R','In-person':'I'}
df['RemoteWork'].map(mymap)
# Out:
# 0        NaN
# 1          R
# 2          H
# 3          H
# 4          R
#         ...
# 89179      R
# 89180      H
# 89181    NaN
# 89182      H
# 89183      H
# Name: RemoteWork, Length: 89184, dtype: object

# %%
df.groupby('ConvertedCompYearly')

# %%
licences = df[['MainBranch','RemoteWork','SurveyEase','first_four']]

# %%
help(pd.pivot)
# Out:
# Help on function pivot in module pandas.core.reshape.pivot:
#
# pivot(data: 'DataFrame', *, columns: 'IndexLabel', index: 'IndexLabel | lib.NoDefault' = <no_default>, values: 'IndexLabel | lib.NoDefault' = <no_default>) -> 'DataFrame'
#     Return reshaped DataFrame organized by given index / column values.
#
#     Reshape data (produce a "pivot" table) based on column values. Uses
#     unique values from specified `index` / `columns` to form axes of the
#     resulting DataFrame. This function does not support data
#     aggregation, multiple values will result in a MultiIndex in the
#     columns. See the :ref:`User Guide <reshaping>` for more on reshaping.
#
#     Parameters
#     ----------
#     data : DataFrame
#     columns : str or object or a list of str
#         Column to use to make new frame's columns.
#     index : str or object or a list of str, optional
#         Column to use to make new frame's index. If not given, uses existing index.
# ...

# %%
df.to_csv('C:/Users/Riyank/Downloads/csv/data.csv', index=False)
